# %%
import pandas as pd

# %%
state_scripts = pd.read_csv('https://www.dropbox.com/s/cgkw4zp5bjc7z2w/arcos-al-statewide-itemized.csv.gz?dl=1', compression='gzip')
state_scripts.head()
# Out:
# /var/folders/n2/5x35hhp53jg1kc9jxswsqhww0000gn/T/ipykernel_31367/1787879430.py:1: DtypeWarning: Columns (3,5,22,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   state_scripts = pd.read_csv('https://www.dropbox.com/s/cgkw4zp5bjc7z2w/arcos-al-statewide-itemized.csv.gz?dl=1', compression='gzip')
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 1  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 2  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 3  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# 4  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
#
#    REPORTER_ZIP REPORTER_COUNTY  ... DOSAGE_UNIT TRANSACTION_ID  \
# 0         11701         SUFFOLK  ...      1000.0            733
# 1         11701         SUFFOLK  ...       300.0            140
# 2         11701         SUFFOLK  ...       500.0           4119
# 3         11701         SUFFOLK  ...        30.0           4222
# 4         11701         SUFFOLK  ...      6000.0           2367
#
#                            Product_Name  \
# 0  HYDROCODONE.BIT & ACETA  10MG & 500M
# 1  HYDROCODONE BIT./IBUPROFEN;7.5MG & 2
# 2   HYDROCODONE BIT.7.5MG/ACETAMINOPHEN
# 3   HYDROCODONE BIT & ACETA 7.5MG/500MG
# 4   HYDROCODONE BIT & ACETA 7.5MG/500MG
#
#                            Ingredient_Name Measure MME_Conversion_Factor  \
# 0  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
# 1  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
# 2  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
# 3  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
# 4  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB                   1.0
#
#             Combined_Labeler_Name   Reporter_family  dos_str        MME
# 0              Par Pharmaceutical  Bellco Drug Corp     10.0   6054.000
# 1  Teva Pharmaceuticals USA, Inc.  Bellco Drug Corp      7.5   1362.150
# 2            Actavis Pharma, Inc.  Bellco Drug Corp      7.5   2270.250
# 3              Par Pharmaceutical  Bellco Drug Corp      7.5    136.215
# 4              Par Pharmaceutical  Bellco Drug Corp      7.5  27243.000
#
# [5 rows x 42 columns]

# %%
state_scripts.columns
script_columns = ['BUYER_STATE', 'BUYER_COUNTY', 'DRUG_NAME', 'TRANSACTION_DATE','Product_Name', 'Ingredient_Name','CALC_BASE_WT_IN_GM', 'DOSAGE_UNIT', 'MME_Conversion_Factor','dos_str', 'MME']
# Out:
# Index(['REPORTER_DEA_NO', 'REPORTER_BUS_ACT', 'REPORTER_NAME',
#        'REPORTER_ADDL_CO_INFO', 'REPORTER_ADDRESS1', 'REPORTER_ADDRESS2',
#        'REPORTER_CITY', 'REPORTER_STATE', 'REPORTER_ZIP', 'REPORTER_COUNTY',
#        'BUYER_DEA_NO', 'BUYER_BUS_ACT', 'BUYER_NAME', 'BUYER_ADDL_CO_INFO',
#        'BUYER_ADDRESS1', 'BUYER_ADDRESS2', 'BUYER_CITY', 'BUYER_STATE',
#        'BUYER_ZIP', 'BUYER_COUNTY', 'TRANSACTION_CODE', 'DRUG_CODE', 'NDC_NO',
#        'DRUG_NAME', 'QUANTITY', 'UNIT', 'ACTION_INDICATOR', 'ORDER_FORM_NO',
#        'CORRECTION_NO', 'STRENGTH', 'TRANSACTION_DATE', 'CALC_BASE_WT_IN_GM',
#        'DOSAGE_UNIT', 'TRANSACTION_ID', 'Product_Name', 'Ingredient_Name',
#        'Measure', 'MME_Conversion_Factor', 'Combined_Labeler_Name',
#        'Reporter_family', 'dos_str', 'MME'],
#       dtype='object')

# %%
state_scripts[['ACTION_INDICATOR', 'ORDER_FORM_NO',
       'CORRECTION_NO', 'STRENGTH', 'TRANSACTION_DATE', 'CALC_BASE_WT_IN_GM',
       'DOSAGE_UNIT', 'TRANSACTION_ID', 'Product_Name', 'Ingredient_Name',
       'Measure', 'MME_Conversion_Factor', 'Combined_Labeler_Name',
       'Reporter_family', 'dos_str', 'MME']]
# Out:
#         ACTION_INDICATOR ORDER_FORM_NO  CORRECTION_NO  STRENGTH  \
# 0                      I           NaN            NaN       0.0
# 1                      I           NaN            NaN       0.0
# 2                    NaN           NaN            NaN       0.0
# 3                    NaN           NaN            NaN       0.0
# 4                    NaN           NaN            NaN       0.0
# ...                  ...           ...            ...       ...
# 5159810              NaN     09X000022            NaN       0.0
# 5159811              NaN     10X000008            NaN       0.0
# 5159812              NaN           NaN            NaN       NaN
# 5159813              NaN     08X000008            NaN       0.0
# 5159814              NaN           NaN         1059.0       0.0
#
#          TRANSACTION_DATE  CALC_BASE_WT_IN_GM  DOSAGE_UNIT  TRANSACTION_ID  \
# 0                 3022006            6.054000       1000.0             733
# 1                 7032006            1.362150        300.0             140
# 2                12132006            2.270250        500.0            4119
# 3                12132006            0.136215         30.0            4222
# 4                 4072007           27.243000       6000.0            2367
# ...                   ...                 ...          ...             ...
# 5159810           8122009            7.172000        200.0            2577
# 5159811           1252010           26.895000       1000.0            3804
# 5159812           8082012            4.540500       1000.0             364
# 5159813           3062008            1.793000        100.0             625
# 5159814           8282008            6.054000       2000.0            4319
#
#                                  Product_Name  \
# 0        HYDROCODONE.BIT & ACETA  10MG & 500M
# 1        HYDROCODONE BIT./IBUPROFEN;7.5MG & 2
# 2         HYDROCODONE BIT.7.5MG/ACETAMINOPHEN
# 3         HYDROCODONE BIT & ACETA 7.5MG/500MG
# 4         HYDROCODONE BIT & ACETA 7.5MG/500MG
# ...                                       ...
# 5159810    OXYCODONE HYDROCHLORIDE 40MG TABS.
# 5159811   OXYCODONE HYDROCHLORIDE 30MG TABLET
# 5159812   HYDROCODONE BIT & ACETA 7.5MG/500MG
# 5159813            OXYCODONE.HCL ER 20MG TABS
# 5159814  HYDROCODONE BIT. & ACETA 5MG/500MG T
#
#                                  Ingredient_Name Measure  \
# 0        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB
# 1        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB
# 2        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB
# 3        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB
# 4        HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB
# ...                                          ...     ...
# 5159810                  OXYCODONE HYDROCHLORIDE     TAB
# 5159811                  OXYCODONE HYDROCHLORIDE     TAB
# 5159812  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB
# 5159813                  OXYCODONE HYDROCHLORIDE     TAB
# 5159814  HYDROCODONE BITARTRATE HEMIPENTAHYDRATE     TAB
#
#          MME_Conversion_Factor                Combined_Labeler_Name  \
# 0                          1.0                   Par Pharmaceutical
# 1                          1.0       Teva Pharmaceuticals USA, Inc.
# 2                          1.0                 Actavis Pharma, Inc.
# 3                          1.0                   Par Pharmaceutical
# 4                          1.0                   Par Pharmaceutical
# ...                        ...                                  ...
# 5159810                    1.5                           SpecGx LLC
# 5159811                    1.5                           SpecGx LLC
# 5159812                    1.0                   Par Pharmaceutical
# 5159813                    1.5                   Par Pharmaceutical
# 5159814                    1.0  Sun Pharmaceutical Industries, Inc.
#
#            Reporter_family  dos_str        MME
# 0         Bellco Drug Corp     10.0   6054.000
# 1         Bellco Drug Corp      7.5   1362.150
# 2         Bellco Drug Corp      7.5   2270.250
# 3         Bellco Drug Corp      7.5    136.215
# 4         Bellco Drug Corp      7.5  27243.000
# ...                    ...      ...        ...
# 5159810  River City Pharma     40.0  10758.000
# 5159811  River City Pharma     30.0  40342.500
# 5159812  River City Pharma      7.5   4540.500
# 5159813  River City Pharma     20.0   2689.500
# 5159814  River City Pharma      5.0   6054.000
#
# [5159815 rows x 16 columns]
