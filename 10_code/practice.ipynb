# %%
import pandas as pd
import datetime as dt

# %%
state_scripts = pd.read_csv('https://www.dropbox.com/s/cgkw4zp5bjc7z2w/arcos-al-statewide-itemized.csv.gz?dl=1', compression='gzip')
state_scripts.head()
# Out:
# /var/folders/n2/5x35hhp53jg1kc9jxswsqhww0000gn/T/ipykernel_31590/1787879430.py:1: DtypeWarning: Columns (3,5,22,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   state_scripts = pd.read_csv('https://www.dropbox.com/s/cgkw4zp5bjc7z2w/arcos-al-statewide-itemized.csv.gz?dl=1', compression='gzip')
#   REPORTER_DEA_NO REPORTER_BUS_ACT     REPORTER_NAME REPORTER_ADDL_CO_INFO  \
# 0       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 1       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 2       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 3       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
# 4       PB0034861      DISTRIBUTOR  BELLCO DRUG CORP                   NaN
#
#         REPORTER_ADDRESS1 REPORTER_ADDRESS2     REPORTER_CITY REPORTER_STATE  \
# 0  5500 NEW HORIZONS BLVD               NaN  NORTH AMITYVILLE             NY
# ...

# %%
state_scripts.loc[state_scripts['BUYER_STATE'] == 'AL','BUYER_COUNTY']
# Out:
# 0          COVINGTON
# 1          COVINGTON
# 2          COVINGTON
# 3          COVINGTON
# 4             WALKER
#              ...
# 5159810       ETOWAH
# 5159811       ETOWAH
# 5159812       ETOWAH
# 5159813      RUSSELL
# 5159814      HOUSTON
# Name: BUYER_COUNTY, Length: 5159815, dtype: object

# %%
state_scripts.columns
script_columns = ['BUYER_STATE', 'BUYER_COUNTY', 'DRUG_NAME', 'TRANSACTION_DATE','Product_Name', 'Ingredient_Name', 'MME']
only_scripts = state_scripts[script_columns]
only_scripts['trans_date'] = pd.to_datetime(only_scripts['TRANSACTION_DATE'], format='%m%d%Y')
only_scripts.loc[only_scripts['BUYER_STATE'] == 'AL']
# Out:
# /var/folders/n2/5x35hhp53jg1kc9jxswsqhww0000gn/T/ipykernel_31590/931344998.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_scripts['trans_date'] = pd.to_datetime(only_scripts['TRANSACTION_DATE'], format='%m%d%Y')
#         BUYER_STATE BUYER_COUNTY    DRUG_NAME  TRANSACTION_DATE  \
# 0                AL    COVINGTON  HYDROCODONE           3022006
# 1                AL    COVINGTON  HYDROCODONE           7032006
# 2                AL    COVINGTON  HYDROCODONE          12132006
# 3                AL    COVINGTON  HYDROCODONE          12132006
# 4                AL       WALKER  HYDROCODONE           4072007
# ...             ...          ...          ...               ...
# ...

# %%
state_pop = pd.read_csv('../00_source_data/US_Population/start_2000.csv', encoding='latin-1')
state_pop.head()
# Out:
#    SUMLEV  REGION  DIVISION  STATE  COUNTY   STNAME         CTYNAME  \
# 0      40       3         6      1       0  Alabama         Alabama
# 1      50       3         6      1       1  Alabama  Autauga County
# 2      50       3         6      1       3  Alabama  Baldwin County
# 3      50       3         6      1       5  Alabama  Barbour County
# 4      50       3         6      1       7  Alabama     Bibb County
#
#   CENSUS2000POP  ESTIMATESBASE2000  POPESTIMATE2000  ...  RDOMESTICMIG2009  \
# 0       4447100            4447382          4451849  ...          2.353249
# 1         43671              43671            43872  ...          3.105529
# 2        140415             140415           141358  ...         16.080204
# 3         29038              29038            29035  ...         -6.345156
# 4         20826              19889            19936  ...         -1.111729
#
#    RNETMIG2001  RNETMIG2002  RNETMIG2003  RNETMIG2004  RNETMIG2005  \
# ...

# %%
pop_columns = ['STNAME', 'CTYNAME', 'POPESTIMATE2000', 'POPESTIMATE2001', 'POPESTIMATE2002','POPESTIMATE2003', 
'POPESTIMATE2004','POPESTIMATE2005', 'POPESTIMATE2006','POPESTIMATE2007', 'POPESTIMATE2008', 'POPESTIMATE2009']
al_pop = state_pop[state_pop['STNAME'] == 'Alabama']
al_pop[pop_columns]

# %%
state_deaths_03 = pd.read_table('../00_source_data/US_VitalStatistics/Underlying Cause of Death, 2003.txt')
al_deaths_03 = state_deaths_03.copy()

# %%
al_deaths_03.drop('Notes', axis=1, inplace=True)
al_deaths_03.dropna(how='all', inplace=True)
al_deaths_03
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL       1001.0  2003.0     2003.0
# 1        Baldwin County, AL       1003.0  2003.0     2003.0
# 2        Baldwin County, AL       1003.0  2003.0     2003.0
# 3        Baldwin County, AL       1003.0  2003.0     2003.0
# 4        Barbour County, AL       1005.0  2003.0     2003.0
# ...                     ...          ...     ...        ...
# 4082  Sweetwater County, WY      56037.0  2003.0     2003.0
# 4083       Teton County, WY      56039.0  2003.0     2003.0
# 4084       Uinta County, WY      56041.0  2003.0     2003.0
# 4085    Washakie County, WY      56043.0  2003.0     2003.0
# 4086      Weston County, WY      56045.0  2003.0     2003.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
only_od = al_deaths_03[al_deaths_03['Drug/Alcohol Induced Cause'].str.contains('Drug poisonings')]
only_od[['COUNTY', 'STATE']] = only_od['County'].str.split(',', 1, expand=True)
only_od
# Out:
# /var/folders/n2/5x35hhp53jg1kc9jxswsqhww0000gn/T/ipykernel_31590/3455202757.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   only_od[['COUNTY', 'STATE']] = only_od['County'].str.split(',', 1, expand=True)
# /var/folders/n2/5x35hhp53jg1kc9jxswsqhww0000gn/T/ipykernel_31590/3455202757.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   only_od[['COUNTY', 'STATE']] = only_od['County'].str.split(',', 1, expand=True)
# /var/folders/n2/5x35hhp53jg1kc9jxswsqhww0000gn/T/ipykernel_31590/3455202757.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
# ...
